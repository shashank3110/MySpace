# %%
import numpy as np

# %%
a=1/100
n=2
u=1#myu
x=np.array((0.5,0.5))

# %%
def get_g(x):
    xt=np.transpose(x)

    g1=np.dot(xt,x)-1
    g2=-x[0]
    return g1,g2

# %%
def get_dg(x):
    dg1=[2*x[0],2*x[1]]
    dg2=[-1,0]
    return dg1,dg2

# %%
def get_fx(x):
    f=0
    for i in range(n):
        f+=x[i]
    return f

# %%
def get_dfx():
    return np.array((1,1))

# %%
def compute_gsum(x):
    
    g1,g2=get_g(x)
    dg1,dg2=get_dg(x)
    sum=np.empty((1,2))
    sum[0][0]=dg1[0]/g1 + dg2[0]/g2
    sum[0][1]=dg1[1]/g1 + dg2[1]/g2
    
    return sum[0]

# %%
def log_barrier(x,u):
    sum=0
    g1,g2=get_g(x)
    dg1,dg2=get_dg(x)
    
    sum=np.log(-g1)+np.log(-g2)
    F=get_fx(x)-u*sum
    return F

# %%
def compute_log_barrier_gradient(x):
    dfx=get_dfx()
    iter=10
    u=1 #myu
    a=0.01#alpha
    while iter>=0:
        DF=dfx-u*compute_gsum(x)
        x,alpha=compute_grad_descent(x,a,DF,u)
        a=alpha
        xp=x
        u=u/2
        iter=iter-1
    return xp

# %%
def compute_grad_descent(x,a,DF,u):

    print(np.shape(DF))
    delta=-(DF/np.linalg.norm(DF))
    theta=1
    w=0.01
    w1=1.2
    w2=0.5
    delmax=np.inf
    dfx=get_dfx()
    i=0
    
    #func=get_fx
    func=log_barrier
    while  np.linalg.norm(a*delta) <theta :

        print("alpha=",a)
        
        
        delta=-(DF/np.linalg.norm(DF))
        j=0
        print("DFT",np.transpose(DF))
        print("**x+a*delta=**",x+a*delta)
        #print( func(x) +w*(np.dot(np.transpose(DF),a*delta)))
        while func(x+a*delta,u) > func(x,u) +w*(np.dot(np.transpose(DF),a*delta)) :
                #num func evaluations
                a=w2*a
                j=j+1
                print("num of inner evaluations",j)
        print("num evaluations",i+1)
       
        
        x=x+a*delta
        DF=dfx-u*compute_gsum(x)
        print("x=",x)
        a=min(w1*a,delmax)
        i=i+1
        if i==10:
            break

    print("End of Gradient Descent alpha=",a)
    return x,a

# %%
print(x)
x_opt=compute_log_barrier_gradient(x)
# Out:
# [0.5 0.5]
# (2,)
# alpha= 0.01
# DFT [1. 3.]
# num evaluations 1
# x= [0.49683772 0.49051317]
# alpha= 0.012
# DFT [0.92596352 2.91401431]
# num evaluations 2
# x= [0.49320364 0.47907667]
# alpha= 0.0144
# DFT [0.84334367 2.81731494]
# num evaluations 3
# x= [0.48907414 0.46528148]
# alpha= 0.01728
# DFT [0.75233111 2.70958922]
# num evaluations 4
# x= [0.48445115 0.44863137]
# alpha= 0.020736
# DFT [0.65360767 2.59078707]
# num evaluations 5
# x= [0.47937877 0.42852533]
# alpha= 0.0248832
# DFT [0.54850421 2.4611424 ]
# num evaluations 6
# x= [0.47396596 0.40423799]
# alpha= 0.02985984
# DFT [0.439184   2.32115159]
# num evaluations 7
# x= [0.46841469 0.3748987 ]
# alpha= 0.035831808
# DFT [0.32884703 2.17148772]
# num evaluations 8
# x= [0.46304954 0.33947084]
# alpha= 0.0429981696
# DFT [0.22193058 2.01282475]
# num evaluations 9
# x= [0.45833719 0.29673167]
# alpha= 0.05159780351999999
# DFT [0.12423237 1.84553713]
# num evaluations 10
# x= [0.45487173 0.24525038]
# End of Gradient Descent alpha= 0.06191736422399999
# (2,)
# alpha= 0.06191736422399999
# DFT [0.52139816 1.33460999]
# num evaluations 1
# x= [0.43234058 0.18757796]
# alpha= 0.07430083706879999
# DFT [0.39928625 1.24113497]
# num evaluations 2
# x= [0.40958577 0.11684725]
# alpha= 0.08916100448255998
# DFT [0.27961197 1.14274276]
# num evaluations 3
# x= [0.38839456 0.03024115]
# alpha= 0.10699320537907198
# DFT [0.17053479 1.03565185]
# num evaluations 4
# x= [ 0.3710107  -0.07533038]
# alpha= 0.12839184645488635
# DFT [0.08541149 0.9120667 ]
# num evaluations 5
# x= [ 0.35903968 -0.20316293]
# alpha= 0.15407021574586363
# DFT [0.04007047 0.75517091]
# num evaluations 6
# x= [ 0.35087598 -0.35701671]
# alpha= 0.18488425889503635
# DFT [0.04318857 0.52361257]
# num evaluations 7
# x= [ 0.33567798 -0.54127525]
# alpha= 0.2218611106740436
# DFT [0.07526704 0.08928564]
# num of inner evaluations 1
# num of inner evaluations 2
# num evaluations 8
# x= [ 0.29992882 -0.58368274]
# alpha= 0.06655833320221308
# DFT [-0.14027716 -0.02516096]
# num of inner evaluations 1
# num evaluations 9
# x= [ 0.33268524 -0.57780735]
# alpha= 0.039934999921327846
# DFT [ 0.09601521 -0.04023364]
# num of inner evaluations 1
# num evaluations 10
# x= [ 0.31426922 -0.57009041]
# End of Gradient Descent alpha= 0.023960999952796706
# (2,)
# alpha= 0.023960999952796706
# DFT [0.4771971  0.50532891]
# num evaluations 1
# x= [ 0.29781809 -0.58751137]
# alpha= 0.028753199943356046
# DFT [0.42358894 0.48112059]
# num evaluations 2
# x= [ 0.27881779 -0.60909227]
# alpha= 0.034503839932027255
# DFT [0.35624513 0.44755264]
# num evaluations 3
# x= [ 0.25732957 -0.63608803]
# alpha= 0.04140460791843271
# DFT [0.27162613 0.3989797 ]
# num evaluations 4
# x= [ 0.23402858 -0.67031384]
# alpha= 0.04968552950211925
# DFT [0.16771316 0.32415775]
# num evaluations 5
# x= [ 0.21119704 -0.71444288]
# alpha= 0.059622635402543096
# DFT [0.05358885 0.19719598]
# num evaluations 6
# x= [ 0.1955614  -0.77197883]
# alpha= 0.07154716248305171
# DFT [-0.01106765 -0.05517973]
# num of inner evaluations 1
# num of inner evaluations 2
# num evaluations 7
# x= [ 0.19907898 -0.75444133]
# alpha= 0.02146414874491551
# DFT [-0.00132726  0.0356996 ]
# num of inner evaluations 1
# num evaluations 8
# x= [ 0.19947771 -0.76516599]
# alpha= 0.012878489246949306
# DFT [ 0.01288927 -0.02095737]
# num of inner evaluations 1
# num evaluations 9
# x= [ 0.19610435 -0.75968107]
# alpha= 0.0077270935481695835
# DFT [-0.01977139  0.01193258]
# num of inner evaluations 1
# num evaluations 10
# x= [ 0.19941216 -0.76167742]
# End of Gradient Descent alpha= 0.00463625612890175
# (2,)
# alpha= 0.00463625612890175
# DFT [0.50432138 0.49900493]
# num evaluations 1
# x= [ 0.1961165  -0.76493834]
# alpha= 0.005563507354682099
# DFT [0.49287914 0.49194821]
# num evaluations 2
# x= [ 0.19217879 -0.76886861]
# alpha= 0.006676208825618519
# DFT [0.47874826 0.48315993]
# num evaluations 3
# x= [ 0.1874797 -0.773611 ]
# alpha= 0.008011450590742222
# DFT [0.46118915 0.47212147]
# num evaluations 4
# x= [ 0.18188149 -0.77934192]
# alpha= 0.009613740708890666
# DFT [0.43920562 0.45810589]
# num evaluations 5
# x= [ 0.17522821 -0.78628151]
# alpha= 0.011536488850668799
# DFT [0.41143089 0.44006052]
# num evaluations 6
# x= [ 0.16734941 -0.79470855]
# alpha= 0.013843786620802557
# DFT [0.37595454 0.41639783]
# num evaluations 7
# x= [ 0.15807211 -0.80498386]
# alpha= 0.016612543944963067
# DFT [0.33006665 0.38459561]
# num evaluations 8
# x= [ 0.147253   -0.81759035]
# alpha= 0.01993505273395568
# DFT [0.26992595 0.34036051]
# num evaluations 9
# x= [ 0.13486589 -0.83320976]
# alpha= 0.023922063280746815
# DFT [0.19039839 0.27565292]
# num evaluations 10
# x= [ 0.12127038 -0.85289293]
# End of Gradient Descent alpha= 0.028706475936896177
# (2,)
# alpha= 0.028706475936896177
# DFT [0.54340799 0.5865638 ]
# num evaluations 1
# x= [ 0.1017613  -0.87395136]
# alpha= 0.03444777112427541
# DFT [0.44213794 0.51630663]
# num evaluations 2
# x= [ 0.07935498 -0.90011633]
# alpha= 0.04133732534913049
# DFT [0.26645827 0.38681959]
# num evaluations 3
# x= [ 0.05590514 -0.93415865]
# alpha= 0.04960479041895659
# DFT [-0.06170998  0.05999244]
# num of inner evaluations 1
# num of inner evaluations 2
# num of inner evaluations 3
# num evaluations 4
# x= [ 0.06035106 -0.93848083]
# alpha= 0.007440718562843488
# DFT [ 0.02964471 -0.01469253]
# num of inner evaluations 1
# num of inner evaluations 2
# num evaluations 5
# x= [ 0.05868436 -0.93765478]
# alpha= 0.0022322155688530463
# DFT [-0.00251496  0.00130212]
# num of inner evaluations 1
# num of inner evaluations 2
# num of inner evaluations 3
# num evaluations 6
# x= [ 0.05893214 -0.93778307]
# alpha= 0.00033483233532795694
# DFT [ 0.00237153 -0.00113558]
# num of inner evaluations 1
# num evaluations 7
# x= [ 0.05878114 -0.93771077]
# alpha= 0.00020089940119677417
# DFT [-0.0005961   0.00025121]
# num of inner evaluations 1
# num of inner evaluations 2
# num evaluations 8
# x= [ 0.05882743 -0.93773027]
# alpha= 6.0269820359032247e-05
# DFT [ 0.00031227 -0.00012806]
# num of inner evaluations 1
# num evaluations 9
# x= [ 0.05879955 -0.93771884]
# alpha= 3.6161892215419345e-05
# DFT [-2.34478356e-04  9.50653723e-05]
# num of inner evaluations 1
# num evaluations 10
# x= [ 0.0588163  -0.93772563]
# End of Gradient Descent alpha= 2.1697135329251605e-05
# (2,)
# alpha= 2.1697135329251605e-05
# DFT [0.50004704 0.49998116]
# num evaluations 1
# x= [ 0.05880096 -0.93774097]
# alpha= 2.6036562395101927e-05
# DFT [0.49990744 0.49985791]
# num evaluations 2
# x= [ 0.05878255 -0.93775938]
# alpha= 3.124387487412231e-05
# DFT [0.49973982 0.49970993]
# num evaluations 3
# x= [ 0.05876045 -0.93778147]
# alpha= 3.749264984894677e-05
# DFT [0.49953854 0.49953223]
# num evaluations 4
# x= [ 0.05873394 -0.93780798]
# alpha= 4.4991179818736124e-05
# DFT [0.49929682 0.49931882]
# num evaluations 5
# x= [ 0.05870213 -0.9378398 ]
# alpha= 5.398941578248335e-05
# DFT [0.49900647 0.49906248]
# num evaluations 6
# x= [ 0.05866395 -0.93787798]
# alpha= 6.478729893898002e-05
# DFT [0.49865766 0.49875451]
# num evaluations 7
# x= [ 0.05861815 -0.93792379]
# alpha= 7.774475872677602e-05
# DFT [0.4982385  0.49838443]
# num evaluations 8
# x= [ 0.05856318 -0.93797877]
# alpha= 9.329371047213122e-05
# DFT [0.49773468 0.49793959]
# num evaluations 9
# x= [ 0.05849723 -0.93804476]
# alpha= 0.00011195245256655746
# DFT [0.49712889 0.4974047 ]
# num evaluations 10
# x= [ 0.05841809 -0.93812394]
# End of Gradient Descent alpha= 0.00013434294307986894
# (2,)
# alpha= 0.00013434294307986894
# DFT [0.7482001  0.74838064]
# num evaluations 1
# x= [ 0.0583231  -0.93821895]
# alpha= 0.00016121153169584273
# DFT [0.74776151 0.74799356]
# num evaluations 2
# x= [ 0.05820913 -0.93833296]
# alpha= 0.00019345383803501126
# DFT [0.74723334 0.74752748]
# num evaluations 3
# x= [ 0.05807236 -0.93846978]
# alpha= 0.0002321446056420135
# DFT [0.74659684 0.74696588]
# num evaluations 4
# x= [ 0.05790825 -0.93863397]
# alpha= 0.0002785735267704162
# DFT [0.74582913 0.74628861]
# num evaluations 5
# x= [ 0.05771133 -0.93883101]
# alpha= 0.00033428823212449944
# DFT [0.74490221 0.74547103]
# num evaluations 6
# x= [ 0.05747504 -0.93906748]
# alpha= 0.0004011458785493993
# DFT [0.74378164 0.74448287]
# num evaluations 7
# x= [ 0.05719152 -0.93935127]
# alpha= 0.0004813750542592791
# DFT [0.74242492 0.74328679]
# num evaluations 8
# x= [ 0.05685134 -0.93969185]
# alpha= 0.0005776500651111349
# DFT [0.74077927 0.74183645]
# num evaluations 9
# x= [ 0.05644317 -0.9401006 ]
# alpha= 0.0006931800781333618
# DFT [0.7387787  0.74007401]
# num evaluations 10
# x= [ 0.05595345 -0.94059118]
# End of Gradient Descent alpha= 0.0008318160937600341
# (2,)
# alpha= 0.0008318160937600341
# DFT [0.86817005 0.86896334]
# num evaluations 1
# x= [ 0.05536553 -0.94117963]
# alpha= 0.0009981793125120408
# DFT [0.86667782 0.86765191]
# num evaluations 2
# x= [ 0.05466011 -0.94188585]
# alpha= 0.001197815175014449
# DFT [0.86484515 0.86604296]
# num evaluations 3
# x= [ 0.05381371 -0.94273342]
# alpha= 0.0014373782100173388
# DFT [0.86258309 0.86405953]
# num evaluations 4
# x= [ 0.0527982  -0.94375066]
# alpha= 0.0017248538520208065
# DFT [0.85977374 0.86160005]
# num evaluations 5
# x= [ 0.05157984 -0.94497161]
# alpha= 0.0020698246224249675
# DFT [0.85625782 0.85852793]
# num evaluations 6
# x= [ 0.05011819 -0.94643714]
# alpha= 0.002483789546909961
# DFT [0.85181515 0.85465534]
# num evaluations 7
# x= [ 0.04836481 -0.94819636]
# alpha= 0.002980547456291953
# DFT [0.84613278 0.84971707]
# num evaluations 8
# x= [ 0.04626171 -0.95030838]
# alpha= 0.0035766569475503434
# DFT [0.83875082 0.8433263 ]
# num evaluations 9
# x= [ 0.04373952 -0.95284433]
# alpha= 0.004291988337060412
# DFT [0.82896474 0.83489584]
# num evaluations 10
# x= [ 0.04071546 -0.95589002]
# End of Gradient Descent alpha= 0.005150386004472494
# (2,)
# alpha= 0.005150386004472494
# DFT [0.90781898 0.9117443 ]
# num evaluations 1
# x= [ 0.03708145 -0.95953974]
# alpha= 0.006180463205366993
# DFT [0.89837603 0.90377932]
# num evaluations 2
# x= [ 0.03272433 -0.96392307]
# alpha= 0.007416555846440392
# DFT [0.88429533 0.89208234]
# num evaluations 3
# x= [ 0.02750307 -0.96919031]
# alpha= 0.00889986701572847
# DFT [0.86155669 0.87362164]
# num evaluations 4
# x= [ 0.02125382 -0.97552707]
# alpha= 0.010679840418874162
# DFT [0.81967638 0.84087545]
# num evaluations 5
# x= [ 0.01379905 -0.98317464]
# alpha= 0.012815808502648995
# DFT [0.72016831 0.76848414]
# num evaluations 6
# x= [ 0.00503564 -0.99252598]
# alpha= 0.015378970203178794
# DFT [0.22692588 0.47842849]
# num evaluations 7
# x= [-0.00155504 -1.00642114]
# alpha= 0.01845476424381455
# DFT [3.51292883 1.61017401]
# num evaluations 8
# x= [-0.01833147 -1.01411073]
# alpha= 0.02214571709257746
# DFT [1.21807003 1.27551014]
# num evaluations 9
# x= [-0.03362609 -1.03012659]
# alpha= 0.026574860511092948
# DFT [1.12038458 1.12919683]
# num evaluations 10
# x= [-0.0523436  -1.04899132]
# End of Gradient Descent alpha= 0.03188983261331153
# (2,)
# alpha= 0.03188983261331153
# DFT [1.0392963  1.03973543]
# num evaluations 1
# x= [-0.07488835 -1.0715456 ]
# alpha= 0.03826779913597384
# DFT [1.0279823  1.02721215]
# num evaluations 2
# x= [-0.10195791 -1.09859487]
# alpha= 0.04592135896316861
# DFT [1.02098896 1.01974812]
# num evaluations 3
# x= [-0.13444895 -1.13104643]
# alpha= 0.05510563075580233
# DFT [1.01629317 1.01485879]
# num evaluations 4
# x= [-0.17344202 -1.16998447]
# alpha= 0.06612675690696279
# DFT [1.01295921 1.01145582]
# num evaluations 5
# x= [-0.22023541 -1.21670841]
# alpha= 0.07935210828835534
# DFT [1.01049498 1.00898642]
# num evaluations 6
# x= [-0.27638773 -1.27277689]
# alpha= 0.09522252994602641
# DFT [1.00861704 1.00713977]
# num evaluations 7
# x= [-0.34376955 -1.34006003]
# alpha= 0.11426703593523169
# DFT [1.0071508  1.00572753]
# num evaluations 8
# x= [-0.42462566 -1.42080187]
# alpha= 0.13712044312227803
# DFT [1.00598305 1.00462892]
# num evaluations 9
# x= [-0.52164973 -1.51769534]
# alpha= 0.16454453174673364
# DFT [1.00503748 1.00376289]
# num evaluations 10
# x= [-0.63807409 -1.63397205]
# End of Gradient Descent alpha= 0.19745343809608037
# (2,)
# alpha= 0.19745343809608037
# DFT [1.0021305  1.00153652]
# num evaluations 1
# x= [-0.77773614 -1.77355132]
# alpha= 0.23694412571529644
# DFT [1.00180795 1.00125946]
# num evaluations 2
# x= [-0.9453268  -1.94105023]
# alpha= 0.2843329508583557
# DFT [1.00153733 1.00103545]
# num evaluations 3
# x= [-1.14643094 -2.14205359]
# alpha= 0.3411995410300268
# DFT [1.00130854 1.00085335]
# num evaluations 4
# x= [-1.3877503  -2.38326325]
# alpha= 0.40943944923603215
# DFT [1.00111402 1.00070466]
# num evaluations 5
# x= [-1.67732691 -2.67272145]
# alpha= 0.49132733908323856
# DFT [1.00094797 1.00058281]
# num evaluations 6
# x= [-2.02481118 -3.02007895]
# alpha= 0.5895928068998862
# DFT [1.0008059  1.00048267]
# num evaluations 7
# x= [-2.44178358 -3.43691668]
# alpha= 0.7075113682798635
# DFT [1.00068424 1.00040017]
# num evaluations 8
# x= [-2.94214068 -3.93713174]
# alpha= 0.8490136419358362
# DFT [1.00058007 1.00033207]
# num evaluations 9
# x= [-3.54255839 -4.53740063]
# End of Gradient Descent alpha= 1.0188163703230033
# /home/shashanks/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log

# %%
d=np.array((1,2))
x=[0.5,0.5]
a=1/100
#a*d
x=x+a*d

# %%
get_fx([0.51 ,0.53])
# Out:
# 1.04

# %%
x_opt
# Out:
# array([-3.54255839, -4.53740063])
